# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Ошибки-данных" data-toc-modified-id="Ошибки-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Ошибки данных</a></span></li><li><span><a href="#Замена-типов-данных" data-toc-modified-id="Замена-типов-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Замена типов данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-создания-пользовательских-профилей-get_profiles()" data-toc-modified-id="Функция-для-создания-пользовательских-профилей-get_profiles()-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция для создания пользовательских профилей get_profiles()</a></span></li><li><span><a href="#Функция-для-расчёта-удержания-get_retention()" data-toc-modified-id="Функция-для-расчёта-удержания-get_retention()-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Функция для расчёта удержания get_retention()</a></span></li><li><span><a href="#Функция-для-расчёта-конверсии-get_conversion()" data-toc-modified-id="Функция-для-расчёта-конверсии-get_conversion()-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Функция для расчёта конверсии get_conversion()</a></span></li><li><span><a href="#Функция-для-расчёта-LTV-и-ROI-get_ltv()" data-toc-modified-id="Функция-для-расчёта-LTV-и-ROI-get_ltv()-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Функция для расчёта LTV и ROI get_ltv()</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма-filter_data()" data-toc-modified-id="Функция-для-сглаживания-фрейма-filter_data()-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Функция для сглаживания фрейма filter_data()</a></span></li><li><span><a href="#Функция-для-визуализации-удержания-plot_retention()" data-toc-modified-id="Функция-для-визуализации-удержания-plot_retention()-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Функция для визуализации удержания plot_retention()</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии-plot_conversion()" data-toc-modified-id="Функция-для-визуализации-конверсии-plot_conversion()-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Функция для визуализации конверсии plot_conversion()</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI-plot_ltv_roi()" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-plot_ltv_roi()-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI plot_ltv_roi()</a></span></li><li><span><a href="#Функция-построения-графика-hist_maker_plot()" data-toc-modified-id="Функция-построения-графика-hist_maker_plot()-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Функция построения графика hist_maker_plot()</a></span></li><li><span><a href="#Функция-сводки-данных-по-пользователям-pivot_table()" data-toc-modified-id="Функция-сводки-данных-по-пользователям-pivot_table()-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Функция сводки данных по пользователям pivot_table()</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-стран-пользователей" data-toc-modified-id="Анализ-стран-пользователей-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ стран пользователей</a></span></li><li><span><a href="#Анализ-девайсов-пользователей" data-toc-modified-id="Анализ-девайсов-пользователей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Анализ девайсов пользователей</a></span></li><li><span><a href="#Анализ-рекламных-каналов-привлечения-пользователей" data-toc-modified-id="Анализ-рекламных-каналов-привлечения-пользователей-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Анализ рекламных каналов привлечения пользователей</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Маркетинг</a></span></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-общей-окупаемости-рекламы" data-toc-modified-id="Анализ-общей-окупаемости-рекламы-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Анализ общей окупаемости рекламы</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-устройствам-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по устройствам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-странам-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по странам</a></span></li><li><span><a href="#Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Анализ-окупаемости-рекламы-с-разбивкой-по-рекламным-каналам-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Анализ окупаемости рекламы с разбивкой по рекламным каналам</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Анализ бизнес-показателей приложения Procrastinate Pro+

# %% [markdown]
# Несколько прошлых месяцев бизнес развлекательного приложения Procrastinate Pro+ постоянно нес убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Необходимо выявить причины этой ситуации.
#
# В распоряжении есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов. Необходимо изучить, как люди пользуются продуктом, когда они начинают покупать, сколько денег приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
# **Цель исследования** — определить поведение потребителей и выяснить причины убыточности бизнеса приложения. Сформулировать рекомендации для рекламного отдела.
#
# *В процессе анализа мы ответим на следующие вопросы:*
# - Как выглядит профиль пользователя?
# - Как были распределены финансы на маркетинг?
# - Какие факторы (и как) влияют на окупаемость рекламы?
#
# **Ход исследования** — данные новых пользователей содержатся в файлах `/datasets/visits_info_short.csv`, `/datasets/orders_info_short.csv` и `/datasets/costs_info_short.csv`. О качестве данных ничего не известно. Поэтому перед проведением анализа понадобится обзор данных.
#
# **Шаг 1. Открыть таблицы и изучить общую информацию о данных**
# - `/datasets/visits_info_short.csv` — данные о визитах
# - `/datasets/orders_info_short.csv` — данные о заказах
# - `/datasets/costs_info_short.csv`  — данные о расходах
#
# **Шаг 2. Подготовить данные**
#
# Оптимизировать данные для анализа. Убедиться, что тип данных в каждой колонке — правильный.
#
# **Шаг 3. Задать функции для расчета и анализа LTV, ROI, удержания и конверсии**
#
# Воспользуемся функциями `get_profiles()`, `get_retention()`, `get_conversion()` и `get_ltv()`. А также функциями для визуализации этих метрик — `filter_data()`, `plot_retention()`, `plot_conversion()`, `plot_ltv_roi()` и `hist_maker_plot()`.
#
# **Шаг 4. Провести исследовательский анализ данных**
#
# Построить профили пользователей. Определите минимальную и максимальную дату привлечения пользователей.
#
# Выяснить:
# - Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# - Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# - По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?
#
# **Шаг 5. Маркетинг**
#
# Ответить на вопросы:
#
# - Сколько денег потратили? (всего / на каждый источник / по времени)
# - Сколько в среднем стоило привлечение одного покупателя из каждого источника?
#
# **Шаг 6. Оценить окупаемость рекламы для привлечения пользователей**
#
# С помощью LTV и ROI:
# - Проанализировать общую окупаемость рекламы;
# - Проанализировать окупаемость рекламы с разбивкой по устройствам;
# - Проанализировать окупаемость рекламы с разбивкой по странам;
# - Проанализировать окупаемость рекламы с разбивкой по рекламным каналам.
# Описать проблемы, которые были обнаружены.
#
# Ответить на вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости? Изучить конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
# Описать возможные причины обнаруженных проблем и сформулировать рекомендации для рекламного отдела.
#
# *При решении этого шага считать, что данные 1-го ноября 2019 года и что в организации принято считать, что окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.*
#
# - Нужно ли включать в анализ органических пользователей?
#
# **Шаг 7. Написать общий вывод**
# - Выделить причины неэффективности привлечения пользователей;
# - Сформулировать рекомендации для отдела маркетинга для повышения эффективности.
#
# *Оформление: выполнить задание в Jupyter Notebook. Заполнить программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Применить форматирование и заголовки.*

# %% [markdown]
# ## Обзор данных

# %% [markdown]
# Загружаем библиотеки и пакеты, необходимые для исследования.

# %%
import pandas as pd # импорт библиотеки pandas для работы с таблицами
import seaborn as sns # импорт библиотеки seaborn для визуализации данных
import matplotlib.pyplot as plt # импорт библиотеки matplotlib.pyplot для продвинутой работы с графиками
from scipy import stats as st # импорт пакета scipy для поиска вероятностей попадания значений в интервалы
import numpy as np # импорт библиотеки numpy для работы с высокоуровневыемыми математическими функциями
from datetime import datetime, timedelta 

# %matplotlib inline

pd.set_option('display.max_columns', 50) # оптимизация отображения данных

# %% [markdown]
# Распакуем данные пользователей и сохраним в соответствующие датафреймы. Исследуем данные с помощью функции `first_look`.

# %%
# функция получения первичной информации о датафрейме
def first_look (df): 
    print('------------- Первые 5 строк -------------')
    display(df.head())
    print('')
    print('')
    print('------------- Общая информация о таблице -------------')
    df.info()
    print('')
    print('')
    print('------------- Пропуски -------------')
    count = 0
    for element in df.columns:
        if df[element].isna().sum() > 0:
            print(element, ' — ', df[element].isna().sum(), 'пропуска(ов)')
            count += 1
    if count == 0:
        print('Пропусков НЕТ')
    print('')
    print('')
    print('------------- Дубликаты -------------')
    if df.duplicated().sum() > 0:
        print(df.duplicated().sum(), 'дубликата(ов)')
    else:
        print('Дубликатов НЕТ')
    print('')
    print('')
#    print('------------- Наиболее популярные уникальные значения -------------')    
#    for column in df:
#        print(df[column].value_counts())

# %% [markdown]
# Прочитаем файлы `/datasets/visits_info_short.csv`, `/datasets/orders_info_short.csv` и `/datasets/costs_info_short.csv` из папки `/datasets` и сохраним их в переменных `df_visits`, `df_orders` и `df_costs` соответственно:

# %%
df_visits = pd.read_csv('/datasets/visits_info_short.csv')
df_orders = pd.read_csv('/datasets/orders_info_short.csv')
df_costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# Исследуем данные таблиц с помощью функции `first_look`.

# %%
first_look(df_visits)
# Out:
# ------------- Первые 5 строк -------------
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40
# ------------- Общая информация о таблице -------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
# ...

# %% [markdown]
# В таблице 6 столбцов. Типы данных в столбцах — `int64(1)`, `object(5)`.
#
# **Согласно документации к данным:**
#
# Таблица `visits_log_short` (лог сервера с информацией о посещениях сайта):
#
# - `User Id` — уникальный идентификатор пользователя
# - `Device` — категория устройства пользователя
# - `Session Start` — дата и время начала сессии
# - `Session End` — дата и время окончания сессии
# - `Channel` — идентификатор рекламного источника, из которого пришел пользователь
# - `Region` — страна пользователя
#
# ✔️ **Соблюдаются требования к таблице:**
# - Отсутствуют явные дубликаты;
# - Отсутствуют пропуски данных.
#
# ❌ **Были замечены нарушения:**
# - Нарушения в стилистике названий, необходимо привести к «змеиному_регистру»;
# - Потребуется замена типа данных в столбцах `Session Start` и `Session End` на дату.

# %%
first_look(df_orders)
# Out:
# ------------- Первые 5 строк -------------
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99
# ------------- Общая информация о таблице -------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#
#
# ------------- Пропуски -------------
# Пропусков НЕТ
#
#
# ------------- Дубликаты -------------
# Дубликатов НЕТ

# %% [markdown]
# В таблице 3 столбца. Типы данных в столбцах —  `float64(1)`, `int64(1)`, `object(1)`.
#
# **Согласно документации к данным:**
#
# Таблица `orders_log_short` (информация о заказах):
#
# - `User Id` — уникальный id пользователя, который сделал заказ
# - `Event Dt` — дата и время покупки
# - `Revenue` — выручка
#
# ✔️ **Соблюдаются требования к таблице:**
# - Отсутствуют явные дубликаты;
# - Отсутствуют пропуски данных.
#
# ❌ **Были замечены нарушения:**
# - Нарушения в стилистике названий, необходимо привести к «змеиному_регистру»;
# - Потребуется замена типа данных в столбце `Event Dt` на дату.

# %%
first_look(df_costs)
# Out:
# ------------- Первые 5 строк -------------
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# ------------- Общая информация о таблице -------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
#
#
# ------------- Пропуски -------------
# Пропусков НЕТ
#
#
# ------------- Дубликаты -------------
# Дубликатов НЕТ

# %% [markdown]
# В таблице 3 столбца. Типы данных в столбцах —  `float64(1)`, `int64(1)`, `object(1)`.
#
# **Согласно документации к данным:**
#
# Таблица `costs_short` (информация о затратах на маркетинг):
#
# - `Channel` — идентификатор рекламного источника
# - `Dt` — дата
# - `Costs` — затраты на этот рекламный источник в этот день
#
# ✔️ **Соблюдаются требования к таблице:**
# - Отсутствуют явные дубликаты;
# - Отсутствуют пропуски данных.
#
# ❌ **Были замечены нарушения:**
# - Нарушения в стилистике названий, необходимо привести к «змеиному_регистру»;
# - Потребуется замена типа данных в столбце `Dt` на дату.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Ошибки данных

# %% [markdown]
# Приведем названия столбцов к нижнему регистру в таблицах методом `str.lower()` и избавимся от пробелов методом `replace()`.

# %%
df_visits.columns = [x.lower().replace(' ', '_') for x in df_visits.columns]
df_orders.columns = [x.lower().replace(' ', '_') for x in df_orders.columns]
df_costs.columns = [x.lower().replace(' ', '_') for x in df_costs.columns]

# %% [markdown]
# Проверим результат. Для этого выведем на экран названия столбцов:

# %%
df_visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %%
df_orders.columns
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
df_costs.columns
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# ### Замена типов данных

# %% [markdown]
# Ранее мы опеределили столбцы для которых необходима замена типов данных:
#
# - `df_visits`  → `session_start`, `session_end`
# - `df_orders`  → `event_dt`
# - `df_costs`  → `dt`

# %%
df_visits['session_start'] = pd.to_datetime(df_visits['session_start'], format="%Y.%m.%d %H:%M:%S")
df_visits['session_end'] = pd.to_datetime(df_visits['session_end'], format="%Y.%m.%d %H:%M:%S")

df_orders['event_dt'] = pd.to_datetime(df_orders['event_dt'], format="%Y.%m.%d %H:%M:%S")

df_costs['dt'] = pd.to_datetime(df_costs['dt']).dt.date

# %% [markdown]
# Проверим типы данных после изменения.

# %%
df_visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
df_costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# ### Выводы

# %% [markdown]
# В процессе предобработки таблиц мы исправили две проблемы:
# - Ошибки названий;
# - Неверные типы данных.
#
# Теперь можно перейти к анализу данных.

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# Соберём функции для создания профилей, расчёта удержания, конверсии, LTV и ROI: `get_profiles()`, `get_retention()`, `get_conversion()` и `get_ltv()`.

# %% [markdown]
# ### Функция для создания пользовательских профилей get_profiles()

# %%
# функция для создания пользовательских профилей
def get_profiles(sessions, orders, ad_costs, event_names=[]):
    
    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first'
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index())

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')
    
    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left')

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для расчёта удержания get_retention()

# %%
# функция для расчёта удержания
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id' : 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта конверсии get_conversion()

# %%
# функция для расчёта конверсии
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для расчёта LTV и ROI get_ltv()

# %%
# функция для расчёта LTV и ROI
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # сохраняем в датафрейм данные пользователей и значения CAC, 
        # добавив параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# А также функции для визуализации этих метрик — `filter_data()`, `plot_retention()`, `plot_conversion()`, `plot_ltv_roi()` и `hist_maker_plot()`.

# %% [markdown]
# ### Функция для сглаживания фрейма filter_data()

# %%
# функция для сглаживания фрейма
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации удержания plot_retention()

# %%
# функция для визуализации удержания
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации конверсии plot_conversion()

# %%
# функция для визуализации конверсии
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean' 
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для визуализации LTV и ROI plot_ltv_roi()

# %%
# функция для визуализации LTV и ROI
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция построения графика hist_maker_plot()

# %%
# функция построения графика
def hist_maker_plot(df, groupby, category, sort, ax): # столбец группировки, категория группировки, сортировка, порядок графика
    
    # группировка и создание сводной таблицы
    all_groupby = df.groupby(groupby)[category].sum().reset_index().sort_values(by=category, ascending=sort)[:5]
    
    # построение графика
    plot = sns.barplot(x=all_groupby[groupby], y=all_groupby[category], color='blue', alpha=0.5, ec='black', ax=axes[ax])
    
    # добавление процентов на график
    total = sum(df[category]) # расчет общих продаж региона
    for p in plot.patches: # цикл для каждого столбца графика
        width = p.get_width() # ширина
        height = p.get_height() # высота
        x, y = p.get_xy()
        percentage = '{:.1f}%'.format(100 * p.get_height() / total) # расчет процентов
        
        plot.annotate(percentage, (x + width / 2, y + height * 1.01), ha='center') # размещение процентов


    plt.ylabel(category)
    plot.set_xlabel(groupby)
    plot.set_title('Распределение {} по {}'.format(category, groupby))

# %% [markdown]
# ### Функция сводки данных по пользователям pivot_table()

# %%
# функция сводки данных по пользователям
def pivot_table(df, column):
    
    table = pd.DataFrame()
   
    table['users'] = df.groupby(column)['user_id'].count() # общее количество пользователей
    table['users,%'] = ((table['users'] / df[column].count())) # общий процент пользователей
    table['payer_users'] = df.query('payer == True').groupby(column)['user_id'].count() # количество платящих пользователей
    table['payer_users,%'] = ((table['payer_users'] / table['users'])) # процент платящих пользователей от общего числа
    
    return table.sort_values(by='users,%', ascending=False).style.format({'users,%' : '{:.2%}', 'payer_users,%' : '{:.2%}'})

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Построим профили пользователей воспользовавшись функцией `get_profiles` и сохраним данные в переменную `df_profiles`.

# %%
df_profiles = get_profiles(df_visits, df_orders, df_costs)

# %% [markdown]
# Посмотрим на полученные данные с помощью функции `head()`.

# %%
df_profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# Определим минимальную и максимальную дату привлечения пользователей.

# %%
print(df_profiles['first_ts'].min())
print(df_profiles['first_ts'].max())
# Out:
# 2019-05-01 00:00:41
# 2019-10-27 23:59:04

# %% [markdown]
# Полученные данные соответствуют временному интервалу, указанному в задании.

# %% [markdown]
# Обозначим момент анализа и его горизонт.

# %%
observation_date = df_profiles['dt'].max() 
horizon_days = 14

# %% [markdown]
# ### Анализ стран пользователей

# %% [markdown]
# Вызовем функцию `hist_maker_plot()` для отображения графиков распределения всех пользователей по странам в первом случае и только платящих пользователей во втором.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
hist_maker_plot(df_profiles, 'region', 'user_id', False, 0) # график всех пользователей 
hist_maker_plot(df_profiles.query('payer==True'), 'region', 'user_id', False, 1) # график платящих пользователей

# %%
df_profiles.groupby('region')['user_id'].sum()
# Out:
# region
# France            8721079260394761
# Germany           7500868654706280
# UK                8730498320190994
# United States    49950116036552088
# Name: user_id, dtype: int64

# %% [markdown]
# В том и в другом случае мы видим, что большая часть пользователей из США (`United States`): среди всех пользователей они составляют 66,7%, а среди платящих - 77,7%.
#
# Меньше всего пользователей из Германии (`Germany`): среди всех пользователей они составляют 10,0%, а среди платящих - 6,9%.

# %% [markdown]
# Воспользуемся функцией `get_conversion()` для визуализации конверсии.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    df_profiles, df_orders, observation_date, horizon_days, dimensions=['region']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Вызовем функцию `pivot_table()` и изучим количество и доли пользователей по странам.

# %%
pivot_table(df_profiles, 'region')
# Out:
# <style  type="text/css" >
# </style><table id="T_1e5d1_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >users,%</th>        <th class="col_heading level0 col2" >payer_users</th>        <th class="col_heading level0 col3" >payer_users,%</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e5d1_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_1e5d1_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_1e5d1_row0_col1" class="data row0 col1" >66.66%</td>
#                         <td id="T_1e5d1_row0_col2" class="data row0 col2" >6902</td>
# ...

# %% [markdown]
# Конверсия платящих пользователей из США (`United States`) составляет 7%, а из Германии (`Germany`) 4,11%.

# %% [markdown]
# ### Анализ девайсов пользователей

# %% [markdown]
# Рассмотрим распределение пользователей по девайсам:

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
hist_maker_plot(df_profiles, 'device', 'user_id', False, 0) # график всех пользователей
hist_maker_plot(df_profiles.query('payer==True'), 'device', 'user_id', False, 1) # график платящих пользователей

# %% [markdown]
# В общем числе пользователи предпочитают пользоваться `iPhone` - таких 36,3%. Реже всего пользователи используют `Mac` - 20,1%.
#
# Среди платящей аудитории также лидируют `iPhone` - таких 38,0%, меньше всех платят пользователи `PC`.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    df_profiles, df_orders, observation_date, horizon_days, dimensions=['device']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
pivot_table(df_profiles, 'device')
# Out:
# <style  type="text/css" >
# </style><table id="T_522a6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >users,%</th>        <th class="col_heading level0 col2" >payer_users</th>        <th class="col_heading level0 col3" >payer_users,%</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_522a6_level0_row0" class="row_heading level0 row0" >iPhone</th>
#                         <td id="T_522a6_row0_col0" class="data row0 col0" >54479</td>
#                         <td id="T_522a6_row0_col1" class="data row0 col1" >36.32%</td>
#                         <td id="T_522a6_row0_col2" class="data row0 col2" >3382</td>
# ...

# %% [markdown]
# Конверсия платящих пользователей `Mac` составляет 6,36%,  `iPhone` 6,21%, а `PC` 5,05%.

# %% [markdown]
# ### Анализ рекламных каналов привлечения пользователей

# %% [markdown]
# Рассмотрим по каким рекламным каналам шло привлечение пользователей:

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
hist_maker_plot(df_profiles, 'channel', 'user_id', False, 0) # график всех пользователей 
hist_maker_plot(df_profiles.query('payer==True'), 'channel', 'user_id', False, 1) # график платящих пользователей

# %% [markdown]
# Большая часть пользователей пришла органически (`organic`) - 37,6%. Наиболее популярный канал продвижения платных пользователей `FaceBoom` - 40,5% среди всех платящих пользователей.

# %%
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    df_profiles, df_orders, observation_date, horizon_days, dimensions=['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
pivot_table(df_profiles, 'channel')
# Out:
# <style  type="text/css" >
# </style><table id="T_fc37f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >users,%</th>        <th class="col_heading level0 col2" >payer_users</th>        <th class="col_heading level0 col3" >payer_users,%</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc37f_level0_row0" class="row_heading level0 row0" >organic</th>
#                         <td id="T_fc37f_row0_col0" class="data row0 col0" >56439</td>
#                         <td id="T_fc37f_row0_col1" class="data row0 col1" >37.62%</td>
#                         <td id="T_fc37f_row0_col2" class="data row0 col2" >1160</td>
# ...

# %% [markdown]
# Конверсия `FaceBoom` составляет 12,20%. Наименьшая конверсия у `organic` - 2,06%.

# %% [markdown]
# ### Выводы

# %% [markdown]
# - Период привлечения пользователей датируется **1 мая 2019 года** по **27 октября 2019 года**.
# - Пользователи живу в США (`United States`), Англии (`UK`), Франции (`France`) и Германии (`Germany`) (по порядку убывания). Наибольшее количество платящей аудитории составляют жители США (`United States`).
# - Пользователи заходят в приложение через `iPhone`, `Android`, `PC` и `Mac`. Большая часть пользователей пользуется `iPhone`, они же составляют наибольшее число платящей аудитории.
# - Большая часть пользователей пришла органически, а самыми популярными каналами привлечения платной аудитории являются `FaceBoom` и `TipTop`.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# Посмотрим, сколько всего финансов было потрачено на маркетинг:

# %%
df_profiles['acquisition_cost'].sum().round(2)
# Out:
# 105497.3

# %% [markdown]
# За выбранный период времени было затрачено на маркетинг **105 497,3 у.е.**

# %%
cost = df_profiles.pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='sum')

cost.plot(figsize=(15, 5), grid=True, kind='line', linewidth=2, alpha=0.5, legend=True)

plt.title('Расходы на маркетинг по источникам')
plt.xlabel(' ')
plt.ylabel('у.е.')
plt.show()

# %% [markdown]
# Большая часть расходов приходится на `Tip Top` и `FaceBoom`. Затраты на остальные рекламные каналы держатся на стабильно низком уровне.

# %% [markdown]
# Рассмотрим как распределялись расходы во времени.

# %%
df_costs.plot(x='dt', y='costs', figsize=(15, 5), grid=True, kind='line', linewidth=2, alpha=0.5, legend=True)


plt.title('Расходы на маркетинг во времени')
plt.xlabel(' ')
plt.ylabel('у.е.')
plt.show()

# %% [markdown]
# Мы наблюдаем уверенный рост затрат на маркетинг на выбранном периоде времени.

# %% [markdown]
# Из условия задачи мы знаем, что несколько прошлых месяцев бизнес приложения Procrastinate Pro+ постоянно нес убытки - в привлечение пользователей была вложена куча денег, но пользы это не принесло. Посмотрим на данные в табличном варианте.

# %%
df_profiles.groupby('channel')['acquisition_cost'].sum().sort_values(ascending=False)
# Out:
# channel
# TipTop                54751.30
# FaceBoom              32445.60
# WahooNetBanner         5151.00
# AdNonSense             3911.25
# OppleCreativeMedia     2151.25
# RocketSuperAds         1833.00
# LeapBob                1797.60
# lambdaMediaAds         1557.60
# MediaTornado            954.48
# YRabbit                 944.22
# organic                   0.00
# Name: acquisition_cost, dtype: float64

# %% [markdown]
# Изучим CAC показатель -  сколько в среднем стоило привлечение одного покупателя из каждого источника. Исключим из выборки органических пользователей, поскольку на их привлечение не было затрачено средств.

# %%
df_profiles.query('channel != "organic"').groupby('channel')['acquisition_cost'].mean().sort_values(ascending=False)
# Out:
# channel
# TipTop                2.799003
# FaceBoom              1.113286
# AdNonSense            1.008054
# lambdaMediaAds        0.724802
# WahooNetBanner        0.602245
# RocketSuperAds        0.412095
# OppleCreativeMedia    0.250000
# YRabbit               0.218975
# MediaTornado          0.218717
# LeapBob               0.210172
# Name: acquisition_cost, dtype: float64

# %%
cost = df_profiles.pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='mean')

cost.plot(figsize=(15, 5), grid=True, kind='line', linewidth=2, alpha=0.5, legend=True)

plt.title('Динамика САС по каналам привлечения')
plt.xlabel(' ')
plt.ylabel('CAC, у.е.')
plt.show()

# %% [markdown]
# Исходя из данных мы видим, что привлечение одного пользователя `TipTop` обходится примерно в 2,8 у.е., а `FaceBoom` в 1,11 у.е.

# %% [markdown]
# ## Оценка окупаемости рекламы для привлечения пользователей

# %% [markdown]
# ### Анализ общей окупаемости рекламы

# %% [markdown]
# Получим `LTV` и `ROI` с помощью функции для расчёта пожизненной ценности `get_ltv()`. Отобразим полученные данные с помощью функции `plot_ltv_roi()`.

# %%
# LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    df_profiles.query('channel != "organic"'), df_orders, observation_date, horizon_days
)

# построение графиков
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По графикам мы видим, что показатель `ROI` не достигает уровня окупаемости, стабильно растет показатель стоимости привлечения пользователей `CAC`, ранее мы видели скачки в стоимости продвижения по каналу `Tip Top`. Показатель `LTV` находится в относительной стабильности — качество пользователей в периоде остается без существенных изменений.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %% [markdown]
# Ранее мы определили, что пользователи используют 4 вида устройств:

# %%
pivot_table(df_profiles, 'device')
# Out:
# <style  type="text/css" >
# </style><table id="T_54e79_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >users,%</th>        <th class="col_heading level0 col2" >payer_users</th>        <th class="col_heading level0 col3" >payer_users,%</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_54e79_level0_row0" class="row_heading level0 row0" >iPhone</th>
#                         <td id="T_54e79_row0_col0" class="data row0 col0" >54479</td>
#                         <td id="T_54e79_row0_col1" class="data row0 col1" >36.32%</td>
#                         <td id="T_54e79_row0_col2" class="data row0 col2" >3382</td>
# ...

# %% [markdown]
# С учетом представленных данных получим `LTV` и `ROI` с помощью функции для расчёта пожизненной ценности `get_ltv()`. Отобразим результат с помощью функции `plot_ltv_roi()`.

# %%
# LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    df_profiles.query('channel != "organic"'), df_orders, observation_date, horizon_days, dimensions = ['device']
)

# построение графиков
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По показателю `ROI` окупаются пользователи `PC`. Мы видим, что общая окупаемость девайсов упала в летний сезон. Показатель `CAC` отражает наибольшие затраты на привлечение пользователей компании Apple. Динамика `LTV` как и прежде, на относительно стабильном уровне.

# %% [markdown]
# Воспользуемся функцией `get_retention()` для отображения графиков удержания пользователей.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    df_profiles.query('channel != "organic"'), df_visits, observation_date, horizon_days, dimensions = ['device']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Пользователи `PC` имеют наибольший показатель удержания. Сложнее удержать пользователей девайсов от Apple.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %% [markdown]
# Пользователи приложения находятся в 4 регионах:

# %%
pivot_table(df_profiles, 'region')
# Out:
# <style  type="text/css" >
# </style><table id="T_89d87_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >users,%</th>        <th class="col_heading level0 col2" >payer_users</th>        <th class="col_heading level0 col3" >payer_users,%</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89d87_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_89d87_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_89d87_row0_col1" class="data row0 col1" >66.66%</td>
#                         <td id="T_89d87_row0_col2" class="data row0 col2" >6902</td>
# ...

# %% [markdown]
# С учетом представленных данных получим `LTV` и `ROI` с помощью функции для расчёта пожизненной ценности `get_ltv()`. Отобразим результат с помощью функции `plot_ltv_roi()`.

# %%
# LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    df_profiles.query('channel != "organic"'), df_orders, observation_date, horizon_days, dimensions = ['region']
)

# построение графиков
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# По показателю `ROI` мы видим, что пользователи из США (`United States`) не окупаются с мая месяца. Ранее мы установили, что это основная аудитория приложения. Показатель `CAC` отражает, что затраты на рекламу в этом регионе неизменно растут, в то время как в других странах они держатся на относительно одном уровне. `LTV` указывает на отличительную ценность пользователей США.

# %% [markdown]
# Воспользуемся функцией `get_retention()` для отображения графиков удержания пользователей.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    df_profiles.query('channel != "organic"'), df_visits, observation_date, horizon_days, dimensions = ['region']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Несмотря на многочисленность, пользователей США (`United States`) труднее всего удержать в приложении.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %% [markdown]
# Вновь отобразим данные по рекламным каналам.

# %%
pivot_table(df_profiles, 'channel')
# Out:
# <style  type="text/css" >
# </style><table id="T_459d0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >users</th>        <th class="col_heading level0 col1" >users,%</th>        <th class="col_heading level0 col2" >payer_users</th>        <th class="col_heading level0 col3" >payer_users,%</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_459d0_level0_row0" class="row_heading level0 row0" >organic</th>
#                         <td id="T_459d0_row0_col0" class="data row0 col0" >56439</td>
#                         <td id="T_459d0_row0_col1" class="data row0 col1" >37.62%</td>
#                         <td id="T_459d0_row0_col2" class="data row0 col2" >1160</td>
# ...

# %% [markdown]
# С учетом представленных данных получим `LTV` и `ROI` с помощью функции для расчёта пожизненной ценности `get_ltv()`. Отобразим результат с помощью функции `plot_ltv_roi()`.

# %%
# LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    df_profiles.query('channel != "organic"'), df_orders, observation_date, horizon_days, dimensions = ['channel']
)

# построение графиков
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# `ROI` отображает окупаемость большинства рекламных каналов. Пользователи каналов `TipTop`, `FaceBoom` и `AdNonSense` не окупаются, ранее мы установили у них самую высокую конверсию. По показателю `CAC` мы видим, что значительно растет стоимость привлечения пользователей через `TipTop`. По показателю `LTV` выделяется канал `lambdaMediaAds`, кроме того он окупается и не требует высоких затрат.

# %% [markdown]
# Воспользуемся функцией `get_retention()` для отображения графиков удержания пользователей.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    df_profiles.query('channel != "organic"'), df_visits, observation_date, horizon_days, dimensions = ['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Привлеченные пользователи через каналы `AdNonSense` и `FaceBoom` меньше всего пользуются приложением.

# %% [markdown]
# ### Выводы

# %% [markdown]
# Реклама, направленная на привлечение пользователей в целом по показателям LTV и ROI окупается примерно на 80%.
#
# Негативное влияние на окупаемость рекламы оказывают:
# - Девайсы компании Apple (`iPhone`, `Mac`);
# - Пользователи США (`United States`);
# - Рекламные каналы: `TipTop`, `FaceBoom` и `AdNonSense`.
#
# Проблемы с окупаемостью могут быть вызваны высокой стоимостью затрат на продвижение. Приложение акцентируется на целевой аудитории США, однако она имеет самый низкий показатель удержания.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В ходе работы была проведена предобработка данных:
# - Исправлены ошибки в названиях;
# - Исправлены неверные типы данных.
#
# На этапе анализа мы изучили данные по странам, девайсам и каналам продвижения пользователей за период от 1 мая 2019 года по 27 октября 2019 года. Большая часть пользователей живет в США (`United States`), затем в Англии (`UK`), Франции (`France`) и Германии (`Germany`). Наибольшее количество платящей аудитории составляют жители США (`United States`).
# Пользователи заходят в приложение через `iPhone`, `Android`, `PC` и `Mac`. Большая часть пользователей пользуется `iPhone`, они же составляют наибольшее число платящей аудитории.
# Большая часть пользователей пришла органически, а самая высокая конверсия привлечения платной аудитории у `FaceBoom` и `TipTop`.
#
# На этапе анализа окупаемости рекламы мы установили, что реклама, направленная на привлечение пользователей в целом по показателям LTV и ROI окупается примерно на 80%.
# Оценка рекламы по девайсам показала окупаемость пользователей `PC`. Дороже всего обходятся пользователи девайсов Apple.
#
# Пользователи из США (`United States`) не окупаются с мая месяца. Ранее мы установили, что это основная аудитория приложения. Показатель CAC отражает, что затраты на рекламу в этом регионе неизменно растут, в то время как в других странах они держатся на относительно одном уровне.
#
# Рекламные каналы `TipTop`, `FaceBoom` и `AdNonSense` не окупаются, ранее мы установили у них самую высокую конверсию. По показателю CAC мы видим, что значительно растет стоимость привлечения пользователей через `TipTop`. Выделяется канал `lambdaMediaAds`, кроме того он окупается и не требует высоких затрат.
#
# *На основе проведенного анализа причины убыточности бизнеса приложения могут заключаться в акценте на аудиторию с низким уровнем удержания и высокими затратами на каналы продвижения, которые не окупаются.*
#
# **Рекомендации для рекламного отдела**
# - Сместить фокус внимания с США на другие регионы, поскольку у них выше показатель удержания;
# - Рассмотреть в качестве приоритета для продвижения приложения канал `lambdaMediaAds`, поскольку он окупается и не требует высоких затрат;
# - Пользователи `PC` имеют самый высокий показатель удержания, необходимо проверить гипотезу *"пользоваться desktop приложением удобнее, чем мобильной версией"*;
# - Каналы продвижения  `TipTop` и `FaceBoom` имеют наибольшую конверсию, но не окупаются. Необходимо пересмотреть выделенный на них бюджет.
